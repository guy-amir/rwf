# %%
from func_gen import *
import sklearn
import torch
from params import parameters
import model_conf
import dataset_loader
import trainer
import matplotlib.pyplot as plt
import numpy as np


conf = parameters()

x,y = step_gen(range = (0,60),step=0.1)
tdl,vdl = dl_maker(x,y,conf)
data = dataset_loader.DataBunch(tdl,vdl,c=1,features4tree=1)

loss_func =  torch.nn.MSELoss()

learn = model_conf.Learner(*model_conf.get_model(conf,data), loss_func, data)

fig = plt.figure()
ax = plt.subplot(111)
xx = learn.data.valid_dl.ds.x.numpy()
yy = learn.data.valid_dl.ds.y.numpy()
ax.scatter(xx, yy, marker='^', label='$y = numbers')

plt.title('Legend inside')
ax.legend()
plt.show()

device = torch.device('cuda',0)
torch.cuda.set_device(device)

run = trainer.Runner(cb_funcs=conf.cbfs,conf=conf)

for i in range(3,7):
    conf.tree_depth = 2*i
    learn = model_conf.Learner(*model_conf.get_model(conf,data), loss_func, data)
    run.fit(conf.epochs, learn)
    zz = run.recorder.tot_pred.cpu().numpy()
    ax.scatter(xx, zz, marker='*', label=f'{2*i}')

plt.show()
# Out:
# train: [0.20826007596295865, tensor(0.2083, device='cuda:0')]
# valid: [0.21009150418368253, tensor(0.2101, device='cuda:0')]
# train: [0.20744204165330574, tensor(0.2074, device='cuda:0')]
# valid: [0.20880824387675584, tensor(0.2088, device='cuda:0')]
# train: [0.20345714436241644, tensor(0.2035, device='cuda:0')]
# valid: [0.20866636796431107, tensor(0.2087, device='cuda:0')]
# train: [0.19573344520075403, tensor(0.1957, device='cuda:0')]
# valid: [0.2037387424045139, tensor(0.2037, device='cuda:0')]
# train: [0.1839954319284923, tensor(0.1840, device='cuda:0')]
# valid: [0.21139037007033223, tensor(0.2114, device='cuda:0')]
# train: [0.17092931567139885, tensor(0.1709, device='cuda:0')]
# valid: [0.22748039707993017, tensor(0.2275, device='cuda:0')]
# train: [0.1565963877967341, tensor(0.1566, device='cuda:0')]
# valid: [0.24321627376055477, tensor(0.2432, device='cuda:0')]
# train: [0.14420230353056496, tensor(0.1442, device='cuda:0')]
# valid: [0.26324104540275806, tensor(0.2632, device='cuda:0')]
# train: [0.13472424217717566, tensor(0.1347, device='cuda:0')]
# valid: [0.28288687118376143, tensor(0.2829, device='cuda:0')]
# train: [0.12821458465424343, tensor(0.1282, device='cuda:0')]
# valid: [0.2961324826635496, tensor(0.2961, device='cuda:0')]
# train: [0.1197856124953844, tensor(0.1198, device='cuda:0')]
# valid: [0.3104010880595506, tensor(0.3104, device='cuda:0')]
# train: [0.15677838301777247, tensor(0.1568, device='cuda:0')]
# valid: [0.26291775944257023, tensor(0.2629, device='cuda:0')]
# train: [0.13520888902654696, tensor(0.1352, device='cuda:0')]
# valid: [0.25104746192392674, tensor(0.2510, device='cuda:0')]
# train: [0.13065436823451104, tensor(0.1307, device='cuda:0')]
# valid: [0.18994055853949654, tensor(0.1899, device='cuda:0')]
# train: [0.12829692328154152, tensor(0.1283, device='cuda:0')]
# valid: [0.15067504150698882, tensor(0.1507, device='cuda:0')]
# train: [0.12633770615307252, tensor(0.1263, device='cuda:0')]
# valid: [0.13129201561513573, tensor(0.1313, device='cuda:0')]
# train: [0.12428488660214553, tensor(0.1243, device='cuda:0')]
# valid: [0.12372676772300643, tensor(0.1237, device='cuda:0')]
# train: [0.121987347579121, tensor(0.1220, device='cuda:0')]
# valid: [0.1241698120579575, tensor(0.1242, device='cuda:0')]
# train: [0.11951962750942553, tensor(0.1195, device='cuda:0')]
# valid: [0.12795561973494712, tensor(0.1280, device='cuda:0')]
# train: [0.11701853358330418, tensor(0.1170, device='cuda:0')]
# valid: [0.13176697432392775, tensor(0.1318, device='cuda:0')]
# train: [0.2046655493589183, tensor(0.2047, device='cuda:0')]
# valid: [0.20555213003447562, tensor(0.2056, device='cuda:0')]
# train: [0.1832187519737737, tensor(0.1832, device='cuda:0')]
# valid: [0.18748258340238322, tensor(0.1875, device='cuda:0')]
# train: [0.1702584983104497, tensor(0.1703, device='cuda:0')]
# valid: [0.1783036318692294, tensor(0.1783, device='cuda:0')]
# train: [0.15570246758152598, tensor(0.1557, device='cuda:0')]
# valid: [0.1700608224579782, tensor(0.1701, device='cuda:0')]
# train: [0.14407026945655024, tensor(0.1441, device='cuda:0')]
# valid: [0.1509938673539595, tensor(0.1510, device='cuda:0')]
# train: [0.13382386924022466, tensor(0.1338, device='cuda:0')]
# valid: [0.13383051361700501, tensor(0.1338, device='cuda:0')]
# train: [0.12436107616519454, tensor(0.1244, device='cuda:0')]
# valid: [0.11929265417233863, tensor(0.1193, device='cuda:0')]
# train: [0.11532319481693097, tensor(0.1153, device='cuda:0')]
# valid: [0.12136131826073232, tensor(0.1214, device='cuda:0')]
# train: [0.10781762611806689, tensor(0.1078, device='cuda:0')]
# valid: [0.13880310636578183, tensor(0.1388, device='cuda:0')]
# train: [0.10181983074738611, tensor(0.1018, device='cuda:0')]
# valid: [0.2068864456330887, tensor(0.2069, device='cuda:0')]
# train: [0.10038726958469373, tensor(0.1004, device='cuda:0')]
# valid: [0.13955390814578894, tensor(0.1396, device='cuda:0')]
# train: [0.09648228166115225, tensor(0.0965, device='cuda:0')]
# valid: [0.14719014215951015, tensor(0.1472, device='cuda:0')]
# train: [0.09283243245746366, tensor(0.0928, device='cuda:0')]
# valid: [0.17979488950787167, tensor(0.1798, device='cuda:0')]
# train: [0.08532301110414724, tensor(0.0853, device='cuda:0')]
# valid: [0.20870337823424676, tensor(0.2087, device='cuda:0')]
# train: [0.08611507320878517, tensor(0.0861, device='cuda:0')]
# valid: [0.09059551508739741, tensor(0.0906, device='cuda:0')]
# train: [0.08079390264862213, tensor(0.0808, device='cuda:0')]
# valid: [0.0849774678548177, tensor(0.0850, device='cuda:0')]
# train: [0.0779665999151581, tensor(0.0780, device='cuda:0')]
# valid: [0.11223874910913333, tensor(0.1122, device='cuda:0')]
# train: [0.0711946629766208, tensor(0.0712, device='cuda:0')]
# valid: [0.1182185664321437, tensor(0.1182, device='cuda:0')]
# train: [0.07658702224048215, tensor(0.0766, device='cuda:0')]
# valid: [0.08366533722540345, tensor(0.0837, device='cuda:0')]
# train: [0.06891969424575123, tensor(0.0689, device='cuda:0')]
# valid: [0.0949504544036557, tensor(0.0950, device='cuda:0')]
# train: [0.16280528206137282, tensor(0.1628, device='cuda:0')]
# valid: [0.33390052872474746, tensor(0.3339, device='cuda:0')]
# train: [0.18985835592545086, tensor(0.1899, device='cuda:0')]
# valid: [0.19516411212959675, tensor(0.1952, device='cuda:0')]
# train: [0.1874754227215971, tensor(0.1875, device='cuda:0')]
# valid: [0.19968121461193972, tensor(0.1997, device='cuda:0')]
# train: [0.185814074615934, tensor(0.1858, device='cuda:0')]
# valid: [0.20050118186257102, tensor(0.2005, device='cuda:0')]
# train: [0.18468131829257034, tensor(0.1847, device='cuda:0')]
# valid: [0.19661144295124092, tensor(0.1966, device='cuda:0')]
# train: [0.1844380886400517, tensor(0.1844, device='cuda:0')]
# valid: [0.198663172095713, tensor(0.1987, device='cuda:0')]
# train: [0.18465681692854088, tensor(0.1847, device='cuda:0')]
# valid: [0.20333794873170177, tensor(0.2033, device='cuda:0')]
# train: [0.1841815739721801, tensor(0.1842, device='cuda:0')]
# valid: [0.20387711187805793, tensor(0.2039, device='cuda:0')]
# train: [0.1841493862778393, tensor(0.1841, device='cuda:0')]
# valid: [0.20468993138785313, tensor(0.2047, device='cuda:0')]
# train: [0.18416527136048275, tensor(0.1842, device='cuda:0')]
# valid: [0.20467218726572364, tensor(0.2047, device='cuda:0')]
# train: [0.1841462927671214, tensor(0.1841, device='cuda:0')]
# valid: [0.20411761120112257, tensor(0.2041, device='cuda:0')]
# train: [0.1841005163999339, tensor(0.1841, device='cuda:0')]
# valid: [0.20292025864726365, tensor(0.2029, device='cuda:0')]
# train: [0.18403746951278763, tensor(0.1840, device='cuda:0')]
# valid: [0.20117857961943655, tensor(0.2012, device='cuda:0')]
# train: [0.18396518005067436, tensor(0.1840, device='cuda:0')]
# valid: [0.19912675414422545, tensor(0.1991, device='cuda:0')]
# train: [0.18389051826439093, tensor(0.1839, device='cuda:0')]
# valid: [0.1970159549905796, tensor(0.1970, device='cuda:0')]
# train: [0.1838197281111532, tensor(0.1838, device='cuda:0')]
# valid: [0.19496258822354404, tensor(0.1950, device='cuda:0')]
# train: [0.1837554096582517, tensor(0.1838, device='cuda:0')]
# valid: [0.19303061745383523, tensor(0.1930, device='cuda:0')]
# train: [0.1836996885081429, tensor(0.1837, device='cuda:0')]
# valid: [0.19126649336381393, tensor(0.1913, device='cuda:0')]
# train: [0.18365079965164413, tensor(0.1837, device='cuda:0')]
# valid: [0.18972352538445983, tensor(0.1897, device='cuda:0')]
# train: [0.18360688318660603, tensor(0.1836, device='cuda:0')]
# valid: [0.18842571913593947, tensor(0.1884, device='cuda:0')]
# train: [0.1967878389121288, tensor(0.1968, device='cuda:0')]
# valid: [0.21742271654533618, tensor(0.2174, device='cuda:0')]
# train: [0.1982814352310712, tensor(0.1983, device='cuda:0')]
# valid: [0.20960353119204742, tensor(0.2096, device='cuda:0')]
# train: [0.20606679584256452, tensor(0.2061, device='cuda:0')]
# valid: [0.21014978428079625, tensor(0.2101, device='cuda:0')]
# train: [0.16885034361881995, tensor(0.1689, device='cuda:0')]
# valid: [0.20662303886028252, tensor(0.2066, device='cuda:0')]
# train: [0.14966574711586111, tensor(0.1497, device='cuda:0')]
# valid: [0.211808195017805, tensor(0.2118, device='cuda:0')]
# train: [0.13754129172557622, tensor(0.1375, device='cuda:0')]
# valid: [0.21396016592931266, tensor(0.2140, device='cuda:0')]
# train: [0.13427524661543358, tensor(0.1343, device='cuda:0')]
# valid: [0.21465869865032158, tensor(0.2147, device='cuda:0')]
# train: [0.13210655326273904, tensor(0.1321, device='cuda:0')]
# valid: [0.21462400031812262, tensor(0.2146, device='cuda:0')]
# train: [0.1310301159151751, tensor(0.1310, device='cuda:0')]
# valid: [0.2143557962745127, tensor(0.2144, device='cuda:0')]
# train: [0.12932855217017938, tensor(0.1293, device='cuda:0')]
# valid: [0.21301471825801965, tensor(0.2130, device='cuda:0')]
# train: [0.1262942546635718, tensor(0.1263, device='cuda:0')]
# valid: [0.20976004937682488, tensor(0.2098, device='cuda:0')]
# train: [0.12168882379484414, tensor(0.1217, device='cuda:0')]
# valid: [0.20565306538283223, tensor(0.2057, device='cuda:0')]
# train: [0.11654237965446207, tensor(0.1165, device='cuda:0')]
# valid: [0.20343017578125, tensor(0.2034, device='cuda:0')]
# train: [0.11216502403145406, tensor(0.1122, device='cuda:0')]
# valid: [0.20336871676974827, tensor(0.2034, device='cuda:0')]
# train: [0.10854968739979302, tensor(0.1085, device='cuda:0')]
# valid: [0.2033455203277896, tensor(0.2033, device='cuda:0')]
# train: [0.10444840388511543, tensor(0.1044, device='cuda:0')]
# valid: [0.2028961181640625, tensor(0.2029, device='cuda:0')]
# train: [0.09891462563282222, tensor(0.0989, device='cuda:0')]
# valid: [0.20172839694552952, tensor(0.2017, device='cuda:0')]
# train: [0.09116374912546642, tensor(0.0912, device='cuda:0')]
# valid: [0.19477175702952376, tensor(0.1948, device='cuda:0')]
# train: [0.08136401959319613, tensor(0.0814, device='cuda:0')]
# valid: [0.18402941540034132, tensor(0.1840, device='cuda:0')]
# train: [0.07429616368232082, tensor(0.0743, device='cuda:0')]
# valid: [0.29161649761777936, tensor(0.2916, device='cuda:0')]

# %%
plt.show()

# %%
from func_gen import *
import sklearn
import torch
from params import parameters
import model_conf
import dataset_loader
import trainer
import matplotlib.pyplot as plt
import numpy as np

conf = parameters()
conf.epochs = 110
conf.one_batch = True
x,y = step_gen(range = (0,60),step=0.1)
tdl,vdl = dl_maker(x,y,conf)
data = dataset_loader.DataBunch(tdl,vdl,c=1,features4tree=1)
device = torch.device('cuda',0)
torch.cuda.set_device(device)
run = trainer.Runner(cb_funcs=conf.cbfs)
loss_func =  torch.nn.MSELoss()

learn = model_conf.Learner(*model_conf.get_model(conf,data), loss_func, data)
xx = learn.data.valid_dl.ds.x.numpy()
yy = learn.data.valid_dl.ds.y.numpy()
plt.scatter(xx, yy, marker='^')

for i in range(3,8):
    conf.tree_depth = 2*i
    learn = model_conf.Learner(*model_conf.get_model(conf,data), loss_func, data)
    run.fit(conf.epochs, learn)
    zz = run.recorder.tot_pred.cpu().numpy()
    plt.scatter(xx, zz, marker='*')

plt.show()
# Out:
# -----------------------------------------
# AttributeErrorTraceback (most recent call last)
# <ipython-input-2-9d51fa4b22b6> in <module>
#      17 device = torch.device('cuda',0)
#      18 torch.cuda.set_device(device)
# ---> 19 run = trainer.Runner(cb_funcs=conf.cbfs)
#      20 loss_func =  torch.nn.MSELoss()
#      21
#
# ~/Documents/phd/code/rwf/trainer.py in __init__(self, cbs, cb_funcs, conf)
#      14             cbs.append(cb)
#      15         self.stop,self.cbs = False,[TrainEvalCallback()]+cbs
# ---> 16         self.intervals = conf.intervals
#      17
#      18     @property
#
# AttributeError: 'NoneType' object has no attribute 'intervals'

# %%
mu = run.mu
y_hat = run.y_hat
arg_mu = torch.argmax(mu, dim=1).cpu().numpy()
uni_mu = np.unique(arg_mu)
yh = y_hat[arg_mu].detach().cpu().numpy()
yh_orig = y_hat.detach().cpu().numpy()
plt.hist(arg_mu,bins=30)

# %%
uni_mu_dist = mu[:,uni_mu].cpu().numpy()

plt.scatter(xx, yh, marker='^')
plt.scatter(xx, yy, marker='*')
plt.scatter(xx, zz, marker='o')
plt.show()

# %%
for i in range(6):
    plt.scatter(xx, uni_mu_dist.T[i], marker='^')

plt.show()
